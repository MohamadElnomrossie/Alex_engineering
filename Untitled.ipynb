# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
img=plt.imread('2.jpg')

# %%
fig,axes=plt.subplots(2,2,figsize=(15,5))

axes[0,0].imshow(img)

axes[0,1].imshow(img[:,:,0],cmap='gray')
axes[1,0].imshow(img[:,:,1],cmap='gray')
axes[1,1].imshow(img[:,:,2],cmap='gray')
plt.tight_layout()

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (3894, 6000, 3)

# %%
img[:,:,0]
# Out:
# array([[14, 12, 11, ..., 15, 18, 17],
#        [17, 17, 13, ..., 10,  6,  9],
#        [26, 26, 19, ..., 23, 13,  9],
#        ...,
#        [42, 42, 41, ..., 39, 41, 69],
#        [42, 42, 41, ..., 39, 41, 69],
#        [42, 42, 41, ..., 39, 41, 69]], dtype=uint8)

# %%
img.flatten().shape
# Out:
# (70092000,)
